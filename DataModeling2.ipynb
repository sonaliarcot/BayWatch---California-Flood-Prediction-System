# %%
import pandas as pd
import numpy as np
import os
os.chdir(r'/Users/sk/Library/CloudStorage/GoogleDrive-sachinkumar.srinivasamurthy@sjsu.edu/Shared drives/DATA 228 Big Data/Project/data/AWS/redshift final/')
os.listdir()
# Out:
# ['DATE.csv',
#  'FLOOD_EVENTS.csv',
#  'INSURANCE.csv',
#  'Untitled0.ipynb',
#  'COUNTY.csv',
#  'WEATHER.csv',
#  'WEATHER_STATIONS.csv',
#  'COUNTY_DAILY_FLOOD_WEATHER.csv',
#  'CA_COUNTY_YEARLY_INSURANCE_STATS.csv']

# %%
for i in os.listdir():
    print(i)
    df= pd.read_csv(i)
    print(df.columns)
    print(df.info())
    print()
    print()
# Out:
# DATE.csv
# Index(['date', 'year'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6602 entries, 0 to 6601
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    6602 non-null   object
#  1   year    6602 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 103.3+ KB
# None
#
#
# FLOOD_EVENTS.csv
# Index(['event_id', 'date', 'year', 'fips_code', 'location', 'lat', 'lng',
#        'event_type', 'flood_cause', 'flood_impact_days'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3817 entries, 0 to 3816
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_id           3817 non-null   int64
#  1   date               3817 non-null   object
#  2   year               3817 non-null   int64
#  3   fips_code          3817 non-null   int64
# ...

# %%
df= pd.read_csv('COUNTY.csv')
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fips_code    58 non-null     int64
#  1   county_name  58 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB

# %%
df
# Out:
#       fips_code    stationID      lat       lng
# 0             1  US1CAAL0001  37.8123 -122.2160
# 1             1  US1CAAL0002  37.7075 -122.0687
# 2             1  US1CAAL0003  37.7169 -122.0585
# 3             1  US1CAAL0004  37.6483 -121.8745
# 4             1  US1CAAL0006  37.8319 -122.2503
# ...         ...          ...      ...       ...
# 2062         95  USW00093241  38.3775 -121.9586
# 2063         39  USW00093242  36.9850 -120.1106
# 2064         47  USW00093243  37.2381 -120.8825
# 2065         97  USW00093245  38.3208 -123.0747
# 2066         49  USW00094299  41.4836 -120.5614
#
# [2067 rows x 4 columns]

# %% [markdown]
# # DATE TABLE

# %%
dfdate= pd.read_csv('Date.csv')
dfdate
# Out:
#             date  year
# 0     2005-01-03  2005
# 1     2005-01-04  2005
# 2     2005-01-05  2005
# 3     2005-01-06  2005
# 4     2005-01-07  2005
# ...          ...   ...
# 6597  2023-01-26  2023
# 6598  2023-01-27  2023
# 6599  2023-01-28  2023
# 6600  2023-01-29  2023
# 6601  2023-01-30  2023
#
# [6602 rows x 2 columns]

# %%
dfdate['date']= pd.to_datetime(dfdate['date'])

# %%
dfdate.date.min()
# Out:
# Timestamp('2005-01-03 00:00:00')

# %%
dfdate.date.max()
# Out:
# Timestamp('2023-01-30 00:00:00')

# %%
(dfdate.date.max()-dfdate.date.min()).days+1
# Out:
# 6602

# %%
dfdate.to_csv('DATE.csv', index=False)

# %%
dfdate
# Out:
#            date  year
# 0    2005-01-03  2005
# 1    2005-01-04  2005
# 2    2005-01-05  2005
# 3    2005-01-06  2005
# 4    2005-01-07  2005
# ...         ...   ...
# 6597 2023-01-26  2023
# 6598 2023-01-27  2023
# 6599 2023-01-28  2023
# 6600 2023-01-29  2023
# 6601 2023-01-30  2023
#
# [6602 rows x 2 columns]

# %% [markdown]
# # FLOOD EVENTS TABLE

# %%
dffe= pd.read_csv('FLOOD_EVENTS.csv')
dffe
# Out:
#       event_id        date  fips_code             location       lat  \
# 0      5437987  2005-01-03         65             SUN CITY  33.68333
# 1      5436478  2005-01-03         27        DEATH VLY JCT  36.30000
# 2      5438001  2005-01-03         65        LAKE ELSINORE  33.70000
# 3      5437645  2005-01-03        111           COUNTYWIDE  34.48333
# 4      5437646  2005-01-03         37           COUNTYWIDE  34.33333
# ...        ...         ...        ...                  ...       ...
# 3812   1065824  2023-01-16         47              GUSTINE  37.24620
# 3813   1065822  2023-01-16         19           ALDER SPGS  37.06550
# 3814   1069369  2023-01-16         73            ENCINITAS  33.03340
# 3815   1065833  2023-01-17        107  DINUBA SEQUOIA ARPT  36.45890
# 3816   1074521  2023-01-30         59             RED HILL  33.74000
#
#             lng   event_type flood_cause  flood_impact_days
# 0    -117.18333  Flash Flood  Heavy Rain                  0
# ...

# %%
dffe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3817 entries, 0 to 3816
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_id           3817 non-null   int64
#  1   date               3817 non-null   object
#  2   fips_code          3817 non-null   int64
#  3   location           3817 non-null   object
#  4   lat                3817 non-null   float64
#  5   lng                3817 non-null   float64
#  6   event_type         3817 non-null   object
#  7   flood_cause        3817 non-null   object
#  8   flood_impact_days  3817 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 268.5+ KB

# %%
dffe['date']= pd.to_datetime(dffe['date'])

# %%
dffe['date'].min()
# Out:
# Timestamp('2005-01-03 00:00:00')

# %%
dffe['date'].max()
# Out:
# Timestamp('2023-01-30 00:00:00')

# %%
dffe['year']= dffe['date'].dt.year
dffe.columns
# Out:
# Index(['event_id', 'date', 'fips_code', 'location', 'lat', 'lng', 'event_type',
#        'flood_cause', 'flood_impact_days', 'year'],
#       dtype='object')

# %%
dffe= dffe[['event_id', 'date',  'year', 'fips_code', 'location', 'lat', 'lng', 'event_type',
       'flood_cause', 'flood_impact_days']]

dffe
# Out:
#       event_id       date  year  fips_code             location       lat  \
# 0      5437987 2005-01-03  2005         65             SUN CITY  33.68333
# 1      5436478 2005-01-03  2005         27        DEATH VLY JCT  36.30000
# 2      5438001 2005-01-03  2005         65        LAKE ELSINORE  33.70000
# 3      5437645 2005-01-03  2005        111           COUNTYWIDE  34.48333
# 4      5437646 2005-01-03  2005         37           COUNTYWIDE  34.33333
# ...        ...        ...   ...        ...                  ...       ...
# 3812   1065824 2023-01-16  2023         47              GUSTINE  37.24620
# 3813   1065822 2023-01-16  2023         19           ALDER SPGS  37.06550
# 3814   1069369 2023-01-16  2023         73            ENCINITAS  33.03340
# 3815   1065833 2023-01-17  2023        107  DINUBA SEQUOIA ARPT  36.45890
# 3816   1074521 2023-01-30  2023         59             RED HILL  33.74000
#
#             lng   event_type flood_cause  flood_impact_days
# ...

# %%
dffe.to_csv('FLOOD_EVENTS.csv', index=False)

# %%
dffe
# Out:
#       event_id       date  year  fips_code             location       lat  \
# 0      5437987 2005-01-03  2005         65             SUN CITY  33.68333
# 1      5436478 2005-01-03  2005         27        DEATH VLY JCT  36.30000
# 2      5438001 2005-01-03  2005         65        LAKE ELSINORE  33.70000
# 3      5437645 2005-01-03  2005        111           COUNTYWIDE  34.48333
# 4      5437646 2005-01-03  2005         37           COUNTYWIDE  34.33333
# ...        ...        ...   ...        ...                  ...       ...
# 3812   1065824 2023-01-16  2023         47              GUSTINE  37.24620
# 3813   1065822 2023-01-16  2023         19           ALDER SPGS  37.06550
# 3814   1069369 2023-01-16  2023         73            ENCINITAS  33.03340
# 3815   1065833 2023-01-17  2023        107  DINUBA SEQUOIA ARPT  36.45890
# 3816   1074521 2023-01-30  2023         59             RED HILL  33.74000
#
#             lng   event_type flood_cause  flood_impact_days
# ...

# %%
dffe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3817 entries, 0 to 3816
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_id           3817 non-null   int64
#  1   date               3817 non-null   datetime64[ns]
#  2   year               3817 non-null   int64
#  3   fips_code          3817 non-null   int64
#  4   location           3817 non-null   object
#  5   lat                3817 non-null   float64
#  6   lng                3817 non-null   float64
#  7   event_type         3817 non-null   object
#  8   flood_cause        3817 non-null   object
#  9   flood_impact_days  3817 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 298.3+ KB

# %% [markdown]
# # County

# %%
dfc= pd.read_csv('COUNTY.csv')
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fips_code    58 non-null     int64
#  1   county_name  58 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB

# %% [markdown]
# # Insurance

# %%
dfi= pd.read_csv('INSURANCE.csv')
dfi.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3311353 entries, 0 to 3311352
# Data columns (total 13 columns):
#  #   Column                             Non-Null Count    Dtype
# ---  ------                             --------------    -----
#  0   fima_record_id                     3311353 non-null  object
#  1   policy_date                        3311353 non-null  object
#  2   year                               3311353 non-null  int64
#  3   fips_code                          3311353 non-null  int64
#  4   zip_code                           3311353 non-null  int64
#  5   flood_zone                         3311353 non-null  object
#  6   lat                                3311353 non-null  float64
#  7   lng                                3311353 non-null  float64
#  8   occupancy_type                     3311353 non-null  float64
#  9   floors                             3311353 non-null  float64
#  10  policy_cost                        3311353 non-null  int64
# ...

# %% [markdown]
# # CA COUNTY INSURANCE

# %%
dfci= pd.read_csv('CA_COUNTY_YEARLY_INSURANCE_STATS.csv')
dfci
# Out:
#        fips_code  year  log_insured  log_cost  policy_count
# 0              1  2009      21.8967   15.7562         11270
# 1              1  2009      21.8967   15.7562          1248
# 2              1  2009      21.8967   15.7562           366
# 3              1  2009      21.8967   15.7562         14202
# 4              1  2009      21.8967   15.7562           219
# ...          ...   ...          ...       ...           ...
# 33609         99  2022      18.0049   12.6484            15
# 33610         99  2022      18.0049   12.6484            87
# 33611         99  2022      18.0049   12.6484           630
# 33612         99  2022      18.0049   12.6484           826
# 33613         99  2022      18.0049   12.6484           250
#
# [33614 rows x 5 columns]

# %%
dfci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33614 entries, 0 to 33613
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   fips_code     33614 non-null  int64
#  1   year          33614 non-null  int64
#  2   log_insured   33614 non-null  float64
#  3   log_cost      33614 non-null  float64
#  4   policy_count  33614 non-null  int64
# dtypes: float64(2), int64(3)
# memory usage: 1.3 MB

# %% [markdown]
# # Weather

# %%
dfw= pd.read_csv('WEATHER.csv')
dfw
# Out:
#            stationID        date  year  PRCP  SNOW  SNWD  TMAX   TMIN
# 0        US1CAAL0001  2008-10-07  2008   0.0   0.0   NaN   NaN    NaN
# 1        US1CAAL0001  2008-10-08  2008   0.0   0.0   NaN   NaN    NaN
# 2        US1CAAL0001  2008-10-09  2008   0.0   0.0   NaN   NaN    NaN
# 3        US1CAAL0001  2008-10-10  2008   0.0   0.0   NaN   NaN    NaN
# 4        US1CAAL0001  2008-10-11  2008   0.0   0.0   NaN   NaN    NaN
# ...              ...         ...   ...   ...   ...   ...   ...    ...
# 6082225  USW00094299  2023-01-26  2023   0.0   NaN   NaN  56.0 -138.0
# 6082226  USW00094299  2023-01-27  2023   0.0   NaN   NaN  67.0  -93.0
# 6082227  USW00094299  2023-01-28  2023   0.0   NaN   NaN  39.0 -105.0
# 6082228  USW00094299  2023-01-29  2023   5.0   NaN   NaN -10.0 -110.0
# 6082229  USW00094299  2023-01-30  2023   0.0   NaN   NaN -10.0 -171.0
#
# [6082230 rows x 8 columns]

# %%
dfw.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6082230 entries, 0 to 6082229
# Data columns (total 8 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   stationID  6082230 non-null  object
#  1   date       6082230 non-null  object
#  2   year       6082230 non-null  int64
#  3   PRCP       4398724 non-null  float64
#  4   SNOW       2561849 non-null  float64
#  5   SNWD       1439049 non-null  float64
#  6   TMAX       3691206 non-null  float64
#  7   TMIN       3687565 non-null  float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 371.2+ MB

# %% [markdown]
# # Weather Stations

# %%
dfws= pd.read_csv('WEATHER_STATIONS.csv')
dfws
# Out:
#       fips_code    stationID      lat       lng
# 0             1  US1CAAL0001  37.8123 -122.2160
# 1             1  US1CAAL0002  37.7075 -122.0687
# 2             1  US1CAAL0003  37.7169 -122.0585
# 3             1  US1CAAL0004  37.6483 -121.8745
# 4             1  US1CAAL0006  37.8319 -122.2503
# ...         ...          ...      ...       ...
# 2062         95  USW00093241  38.3775 -121.9586
# 2063         39  USW00093242  36.9850 -120.1106
# 2064         47  USW00093243  37.2381 -120.8825
# 2065         97  USW00093245  38.3208 -123.0747
# 2066         49  USW00094299  41.4836 -120.5614
#
# [2067 rows x 4 columns]

# %%
dfws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2067 entries, 0 to 2066
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   fips_code  2067 non-null   int64
#  1   stationID  2067 non-null   object
#  2   lat        2067 non-null   float64
#  3   lng        2067 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 64.7+ KB

# %% [markdown]
# # Weather Flood Table

# %%
dfwf= pd.read_csv('WEATHER_FLOOD_TABLE.csv')
dfwf
# Out:
#         fips_code        date  year  floods_count  PRCP_min  PRCP_max  \
# 0               1  2005-01-03  2005             0         0       117
# 1               1  2005-01-04  2005             0         0        13
# 2               1  2005-01-05  2005             0         0        13
# 3               1  2005-01-06  2005             0         0       109
# 4               1  2005-01-07  2005             0        43       165
# ...           ...         ...   ...           ...       ...       ...
# 382639        115  2023-01-26  2023             0         0         0
# 382640        115  2023-01-27  2023             0         0         0
# 382641        115  2023-01-28  2023             0         0         0
# 382642        115  2023-01-29  2023             0         0       193
# 382643        115  2023-01-30  2023             0         0        10
#
#         PRCP_mean  TEMP_min  TEMP_max  TEMP_mean  SNOW_min  SNOW_max  \
# ...

# %%
dfwf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382644 entries, 0 to 382643
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   fips_code     382644 non-null  int64
#  1   date          382644 non-null  object
#  2   year          382644 non-null  int64
#  3   floods_count  382644 non-null  int64
#  4   PRCP_min      382644 non-null  int64
#  5   PRCP_max      382644 non-null  int64
#  6   PRCP_mean     382644 non-null  int64
#  7   TEMP_min      382644 non-null  int64
#  8   TEMP_max      382644 non-null  int64
#  9   TEMP_mean     382644 non-null  int64
#  10  SNOW_min      382644 non-null  int64
#  11  SNOW_max      382644 non-null  int64
#  12  SNOW_mean     382644 non-null  int64
#  13  SNWD_min      382644 non-null  int64
#  14  SNWD_max      382644 non-null  int64
#  15  SNWD_mean     382644 non-null  int64
#  16  fact_id       382644 non-null  int64
# dtypes: int64(16), object(1)
# ...

# %%
dfwf.columns
# Out:
# Index(['fips_code', 'date', 'year', 'floods_count', 'PRCP_min', 'PRCP_max',
#        'PRCP_mean', 'TEMP_min', 'TEMP_max', 'TEMP_mean', 'SNOW_min',
#        'SNOW_max', 'SNOW_mean', 'SNWD_min', 'SNWD_max', 'SNWD_mean',
#        'fact_id'],
#       dtype='object')

# %%
dfwf= dfwf[['fact_id', 'date', 'year', 'fips_code', 'floods_count', 'PRCP_mean', 'TEMP_mean', 'SNOW_mean', 'SNWD_mean']]
dfwf.columns
# Out:
# Index(['fact_id', 'date', 'year', 'fips_code', 'floods_count', 'PRCP_mean',
#        'TEMP_mean', 'SNOW_mean', 'SNWD_mean'],
#       dtype='object')

# %%
dfwf['fact_id'].value_counts().sort_index()
# Out:
# 1         1
# 2         1
# 3         1
# 4         1
# 5         1
#          ..
# 382640    1
# 382641    1
# 382642    1
# 382643    1
# 382644    1
# Name: fact_id, Length: 382644, dtype: int64

# %%
dfwf.columns=['fw_id', 'date', 'year', 'fips_code', 'floods_count', 'PRCP_mean',
       'TEMP_mean', 'SNOW_mean', 'SNWD_mean']

dfwf
# Out:
#          fw_id        date  year  fips_code  floods_count  PRCP_mean  \
# 0            1  2005-01-03  2005          1             0         38
# 1            2  2005-01-04  2005          1             0          2
# 2            3  2005-01-05  2005          1             0          3
# 3            4  2005-01-06  2005          1             0         12
# 4            5  2005-01-07  2005          1             0        110
# ...        ...         ...   ...        ...           ...        ...
# 382639  382640  2023-01-26  2023        115             0          0
# 382640  382641  2023-01-27  2023        115             0          0
# 382641  382642  2023-01-28  2023        115             0          0
# 382642  382643  2023-01-29  2023        115             0         39
# 382643  382644  2023-01-30  2023        115             0          4
#
#         TEMP_mean  SNOW_mean  SNWD_mean
# 0              69          0          0
# 1              73          0          0
# ...

# %%
dfwf.to_csv('COUNTY_DAILY_FLOOD_WEATHER.csv', index=False)
